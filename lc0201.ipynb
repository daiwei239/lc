# %% [markdown]
# # 题目**3010**✨

# %% [markdown]
# > 除去第一个元素，然后将后面的全部元素中
# > 取最小和次小两个元素，然后将这些值进行相加即可

# %%
def minimumCost(self, nums: List[int]) -> int:
    first = nums[0]
    temp = nums[1:]
    temp.sort()
    second,third = temp[0],temp[1]
    return first+second+third

# %% [markdown]
# # 题目**238**✨✨

# %%
def productExceptSelf(self, nums: List[int]) -> List[int]:
    n = len(nums)
    L = [1]*n
    R = [1]*n

    for i in range(1,n):
        L[i] = L[i-1]*nums[i-1]
    
    for i in range(n-2,-1,-1):
        R[i]=R[i+1]*nums[i+1]

    ans = [1]*n
    for i in range(n):
        ans[i] = L[i]*R[i]
    return ans

# %% [markdown]
# # 题目**134**✨✨

# %%
def canCompleteCircuit(self, gas: List[int], cost: List[int]) -> int:
    n = len(gas)
    profit = [0]*n
    min_gas = float("inf")
    ans = 0
    currs = 0
    for i in range(n):
        s+= gas[i]-cost[i]
        if s<min_gas:
            min_gas=s
            ans = i+1
    return -1 if s<0 else ans

# %% [markdown]
# # 题目**13**✨

# %%
    def romanToInt(self, s: str) -> int:
        hash = {
        "I":1,
        "V":5,
        "X":10,
        "L":50,
        "C":100,
        "D":500,
        "M":1000
        }
        n = len(s)
        total = 0
        for i in range(n-1):
            if hash[s[i]]<hash[s[i+1]]:
                total-=hash[s[i]]
            else:
                total+=hash[s[i]]
        
        return total+hash[s[-1]]

# %% [markdown]
# # 题目**58**✨

# %%
def lengthOfLastWord(self, s: str) -> int:
        
        left =0
        right =0
        for i in range(len(s)-1,-1,-1):
            if right ==0 and s[i] != " ":
                right = i
                continue
            if right != 0 and s[i] ==" ":
                left = i+1
                break
        return right-left+1

# %% [markdown]
# # 题目**14**✨

# %%
class Trie:
    def __init__(self):
        self.id = float("inf")
        self.children = [None]*26
def update(word:str,root:Trie):
    counter = 0
    t = root
    for ch in word:
        i = ord(ch)-ord("a")
        if t.children[i]:
…        root = first(strs[0])

        for wo in strs[1:]:
            update(wo,root)
        return strs[0][:root.id]

# %% [markdown]
# ## 方法2

# %%
def longestCommonPrefix(self, strs: List[str]) -> str:
    s0= str[0]
    for i ,x in enumerate(s0):
        for s in strs:
            if s[i]!=x or i == len(s)
            return s0[:i]
    return s0

# %% [markdown]
# # 题目**151**✨✨

# %%
def reverseWords(self, s: str) -> str:
    word_list = s.split()
    left,right = 0,len(word_list)-1
    while left<right:
        word_list[left],word_list[right]=word_list[right],word_list[left]
        left+=1
        right-=1
    
    return " ".join(word_list)
